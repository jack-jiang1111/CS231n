# %% [markdown]
# # Homework 1: Classifiers

# %% [markdown]
# # Linear Softmax Classifier
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %% [markdown]
# ## Load and preprocess CIFAR-10 dataset

# %%
from keras.datasets import cifar10

def get_CIFAR10_data(num_training=49000, num_validation=1000,
                     num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    (X_train, y_train), (X_test, y_test) = cifar10.load_data()
    
    # All the data comes in the uint8 format, so we need to convert
    # it to floats so that we compute numbers greater than 255.
    X_train = X_train.astype(np.float)
    X_test = X_test.astype(np.float)
    # Also, for convenience we flatten the class arrays.
    y_train = y_train.flatten()
    y_test = y_test.flatten()
    
    # Split the data into train, val, and test sets. In addition we will
    # create a small development set as a subset of the training data;
    # we can use this for development so our code runs faster.
    
    # Our validation set will be num_validation points from the original
    # training set.
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    
    # Our training set will be the first num_train points from the original
    # training set.
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    
    # We will also make a development set, which is a small subset of
    # the training set.
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # We use the first num_test points of the original test set as our
    # test set.
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # third: append the bias dimension of ones (i.e. bias trick) so that our SVM
    # only has to worry about optimizing a single weight matrix W.
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Define a naive Softmax classifier loss function
#
# Next we define the Softmax loss function.  This will be a naive implementation using loops.  Most of the code for this loss function already exists, but you will need to write code of your own to finish it.  Follow the instructions in the TODO section.
#
# Recall that the contribution of a training point $(x_i, y_i)$ to the Softmax loss function is
#
# $$L_i = -\log \left( \frac{\exp(s_{y_i})}{\sum_{j} \exp(s_j)} \right)$$
#
# This is the cross-entropy between the predicted class probabilities, and the distribution with all probability concentrated at $y_i$.  The score $s$ is again parametrized by a linear function $s_j = xW_j$ where $x$ is a single data sample and $W_j$ is the $j$th column of $W$.

# %%
import math


def softmax_loss_naive(W, X, y, reg):
  """
  Softmax loss function, naive implementation (with loops)

  Inputs have dimension D, there are C classes, and we operate on minibatches
  of N examples.

  Inputs:
  - W: A numpy array of shape (D, C) containing weights.
  - X: A numpy array of shape (N, D) containing a minibatch of data.
  - y: A numpy array of shape (N,) containing training labels; y[i] = c means
    that X[i] has label c, where 0 <= c < C.
  - reg: (float) regularization strength

  Returns a tuple of:
  - loss as single float
  - gradient with respect to weights W; an array of same shape as W
  """
  # Initialize the loss and gradient to zero.
  loss = 0.0
  dW = np.zeros_like(W)

  #############################################################################
  # TODO: Compute the softmax loss and its gradient using explicit loops.     #
  # Store the loss in loss and the gradient in dW. If you are not careful     #
  # here, it is easy to run into numeric instability. Don't forget the        #
  # regularization!                                                           #
  #############################################################################

  # compute the loss and the gradient
  num_classes = W.shape[1]
  num_train = X.shape[0]
  loss = 0.0
  for i in range(num_train):
    scores = X[i].dot(W)
    exp_scores = np.exp(scores)

    sum_exp = np.sum(exp_scores)
    loss += -np.log(exp_scores[y[i]]/sum_exp)

    
    probablity = (exp_scores / sum_exp).reshape(-1, 1)

    for j in range(num_classes):
      if j == y[i]:
          dW[:, y[i]] += (probablity[j] - 1) * X[i, :]
      else:
          dW[:, j] += probablity[j] * X[i, :]
  # Do the average
  loss /= num_train
  dW  /= float(num_train)
  # Add regularization to the loss.
  loss += reg * np.sum(W * W)
  dW  += reg * W
  #############################################################################
  #                          END OF YOUR CODE                                 #
  #############################################################################

  return loss, dW

# %%
# Evaluate the naive implementation of the loss we provided for you:
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.372184
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.
#
# **Your answer:** Assume the initial values are all random. What inside the log should be 1 over class number, in this case 10. Therefore, we got -log(1/10) = -log(0.1)

# %%
def grad_check_sparse(f, x, analytic_grad, num_checks=10, h=1e-5):
  """
  sample a few random elements and only return numerical
  in this dimensions.
  """

  for i in range(num_checks):
    ix = tuple([np.random.randint(m) for m in x.shape])

    oldval = x[ix]
    x[ix] = oldval + h # increment by h
    fxph = f(x) # evaluate f(x + h)
    x[ix] = oldval - h # increment by h
    fxmh = f(x) # evaluate f(x - h)
    x[ix] = oldval # reset

    grad_numerical = (fxph - fxmh) / (2 * h)
    grad_analytic = analytic_grad[ix]
    rel_error = abs(grad_numerical - grad_analytic) / (abs(grad_numerical) + abs(grad_analytic))
    print('numerical: %f analytic: %f, relative error: %e' % (grad_numerical, grad_analytic, rel_error))
    
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.148703 analytic: 0.148703, relative error: 3.998535e-07
# numerical: 1.234335 analytic: 1.234335, relative error: 8.074489e-09
# numerical: -5.010418 analytic: -5.010418, relative error: 1.186779e-08
# numerical: 2.716336 analytic: 2.716336, relative error: 9.041799e-09
# numerical: -1.158529 analytic: -1.158529, relative error: 9.982933e-09
# numerical: -2.016098 analytic: -2.016098, relative error: 1.720459e-09
# numerical: 0.249724 analytic: 0.249724, relative error: 1.409614e-07
# numerical: 0.825574 analytic: 0.825574, relative error: 7.837475e-08
# numerical: -0.023527 analytic: -0.023527, relative error: 1.485988e-06
# numerical: -5.314390 analytic: -5.314390, relative error: 3.728868e-09
# numerical: -1.486262 analytic: -1.485771, relative error: 1.650493e-04
# numerical: 1.972190 analytic: 1.964701, relative error: 1.902320e-03
# numerical: -0.524439 analytic: -0.526199, relative error: 1.674840e-03
# numerical: -1.976525 analytic: -1.977254, relative error: 1.844722e-04
# numerical: 1.741519 analytic: 1.744872, relative error: 9.616275e-04
# numerical: 0.853951 analytic: 0.850732, relative error: 1.888464e-03
# numerical: -5.523724 analytic: -5.523115, relative error: 5.512644e-05
# numerical: 0.006625 analytic: 0.006697, relative error: 5.356776e-03
# numerical: -3.030677 analytic: -3.035434, relative error: 7.841946e-04
# numerical: -0.425750 analytic: -0.428280, relative error: 2.961916e-03

# %% [markdown]
# ## Define a vectorized Softmax classifier loss function
#
# Next we define the vectorized (i.e. no loops) version of the Softmax loss function.  Most of the code for this loss function already exists, but you will need to write code of your own to finish it.  Follow the instructions in the TODO section.

# %%
def softmax_loss_vectorized(W, X, y, reg):
  """
  Softmax loss function, vectorized version.

  Inputs and outputs are the same as softmax_loss_naive.
  """
  # Initialize the loss and gradient to zero.
  loss = 0.0
  dW = np.zeros_like(W)

  #############################################################################
  # TODO: Compute the softmax loss and its gradient using no explicit loops.  #
  # Store the loss in loss and the gradient in dW. If you are not careful     #
  # here, it is easy to run into numeric instability. Don't forget the        #
  # regularization!                                                           #
  #############################################################################
  # compute the loss and the gradient
  num_classes = W.shape[1]
  num_train = X.shape[0]
  loss = 0.0
  # measure loss
  scores = np.dot(X,W)
  exp_scores = np.exp(scores)
  sum_exp =  np.sum(np.exp(scores), axis=1)
  correct = np.exp(scores[np.arange(num_train), y])
  probablity = correct /sum_exp
  loss -= np.sum(np.log(probablity))

  # measure dW
  column = np.zeros_like(scores)
  column[np.arange(num_train), y] = 1
  dW = X.T.dot(exp_scores / np.sum(np.exp(scores), axis=1, keepdims=True) - column)
  
  # Do the average
  loss /= num_train
  dW  /= float(num_train)
  # Add regularization to the loss.
  loss += reg * np.sum(W * W)
  dW  += reg * W
  #############################################################################
  #                          END OF YOUR CODE                                 #
  #############################################################################

  return loss, dW

# %%
# Evaluate the naive implementation of the Softmax gradients

# The naive implementation and the vectorized implementation should match, but
# the vectorized version should still be much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.372184e+00 computed in 0.133418s
# vectorized loss: 2.372184e+00 computed in 0.019109s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %% [markdown]
# ## Stochastic Gradient Descent
#
# We now have vectorized and efficient expressions for the loss, the gradient and our gradient matches the numerical gradient. We are therefore ready to do SGD to minimize the loss. Follow the instructions in the TODO sections below.  You may just want to copy the code you wrote for the SVM.

# %%
class Softmax(object):

  def __init__(self):
    self.W = None

  def train(self, X, y, learning_rate=1e-3, reg=1e-5, num_iters=100,
            batch_size=200, verbose=False):
    """
    Train this linear classifier using stochastic gradient descent.

    Inputs:
    - X: A numpy array of shape (N, D) containing training data; there are N
      training samples each of dimension D.
    - y: A numpy array of shape (N,) containing training labels; y[i] = c
      means that X[i] has label 0 <= c < C for C classes.
    - learning_rate: (float) learning rate for optimization.
    - reg: (float) regularization strength.
    - num_iters: (integer) number of steps to take when optimizing
    - batch_size: (integer) number of training examples to use at each step.
    - verbose: (boolean) If true, print progress during optimization.

    Outputs:
    A list containing the value of the loss function at each training iteration.
    """
    num_train, dim = X.shape
    num_classes = np.max(y) + 1 # assume y takes values 0...K-1 where K is number of classes
    if self.W is None:
      # lazily initialize W
      self.W = 0.001 * np.random.randn(dim, num_classes)

    # Run stochastic gradient descent to optimize W
    loss_history = []
    for it in range(num_iters):
      X_batch = None
      y_batch = None

      #########################################################################
      # TODO:                                                                 #
      # Sample batch_size elements from the training data and their           #
      # corresponding labels to use in this round of gradient descent.        #
      # Store the data in X_batch and their corresponding labels in           #
      # y_batch; after sampling X_batch should have shape (dim, batch_size)   #
      # and y_batch should have shape (batch_size,)                           #
      #                                                                       #
      # Hint: Use np.random.choice to generate indices. Sampling with         #
      # replacement is faster than sampling without replacement.              #
      #########################################################################
      random_samples_indx = np.random.choice(num_train,batch_size)
      X_batch = X[random_samples_indx,:]
      y_batch = y[random_samples_indx]
      #########################################################################
      #                       END OF YOUR CODE                                #
      #########################################################################

      # evaluate loss and gradient
      loss, grad = self.loss(X_batch, y_batch, reg)
      loss_history.append(loss)

      # perform parameter update
      #########################################################################
      # TODO:                                                                 #
      # Update the weights using the gradient and the learning rate.          #
      #########################################################################
      self.W += -learning_rate*grad
      #########################################################################
      #                       END OF YOUR CODE                                #
      #########################################################################

      if verbose and it % 100 == 0:
        print('iteration %d / %d: loss %f' % (it, num_iters, loss))

    return loss_history

  def predict(self, X):
    """
    Use the trained weights of this linear classifier to predict labels for
    data points.

    Inputs:
    - X: A numpy array of shape (N, D) containing training data; there are N
      training samples each of dimension D.

    Returns:
    - y_pred: Predicted labels for the data in X. y_pred is a 1-dimensional
      array of length N, and each element is an integer giving the predicted
      class.
    """
    y_pred = np.zeros(X.shape[0])
    ###########################################################################
    # TODO:                                                                   #
    # Implement this method. Store the predicted labels in y_pred.            #
    ###########################################################################
    y_pred = np.argmax(np.dot(X,self.W),axis=1)
    ###########################################################################
    #                           END OF YOUR CODE                              #
    ###########################################################################
    return y_pred
  
  def loss(self, X_batch, y_batch, reg):
    """
    Compute the loss function and its derivative. 
    Subclasses will override this.

    Inputs:
    - X_batch: A numpy array of shape (N, D) containing a minibatch of N
      data points; each point has dimension D.
    - y_batch: A numpy array of shape (N,) containing labels for the minibatch.
    - reg: (float) regularization strength.

    Returns: A tuple containing:
    - loss as a single float
    - gradient with respect to self.W; an array of the same shape as W
    """
    return softmax_loss_vectorized(self.W, X_batch, y_batch, reg)

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = [2.5e4, 5e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
learning_rates_parameter = np.linspace(learning_rates[0], learning_rates[1], 10)
regularization_parameter = np.linspace(regularization_strengths[0], regularization_strengths[1], 10)
for l in learning_rates_parameter:
  for r in regularization_parameter:
    softmax = Softmax()
    loss_hist = softmax.train(X_train, y_train, learning_rate=l, reg=r,num_iters=1500, verbose=True)
    y_train_pred = softmax.predict(X_train)
    training_accuracy = np.mean(y_train == y_train_pred)
    y_val_pred = softmax.predict(X_val)
    validation_accuracy= np.mean(y_val == y_val_pred)
    results[(l,r)] = (training_accuracy,validation_accuracy)

    if validation_accuracy>best_val:
      best_val = validation_accuracy
      best_softmax = softmax
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 775.199520
# iteration 100 / 1500: loss 467.372848
# iteration 200 / 1500: loss 283.513164
# iteration 300 / 1500: loss 172.169574
# iteration 400 / 1500: loss 104.960938
# iteration 500 / 1500: loss 64.352275
# iteration 600 / 1500: loss 39.793405
# iteration 700 / 1500: loss 24.903661
# iteration 800 / 1500: loss 15.923427
# iteration 900 / 1500: loss 10.520853
# iteration 1000 / 1500: loss 7.144133
# iteration 1100 / 1500: loss 5.217552
# iteration 1200 / 1500: loss 3.851909
# iteration 1300 / 1500: loss 3.237460
# iteration 1400 / 1500: loss 2.779304
# iteration 0 / 1500: loss 859.750301
# iteration 100 / 1500: loss 491.447218
# iteration 200 / 1500: loss 281.974373
# iteration 300 / 1500: loss 161.955835
# iteration 400 / 1500: loss 93.647312
# iteration 500 / 1500: loss 54.423244
# iteration 600 / 1500: loss 32.085790
# iteration 700 / 1500: loss 19.328790
# iteration 800 / 1500: loss 11.989147
# iteration 900 / 1500: loss 7.762290
# iteration 1000 / 1500: loss 5.334923
# iteration 1100 / 1500: loss 3.954931
# iteration 1200 / 1500: loss 3.145320
# iteration 1300 / 1500: loss 2.733486
# iteration 1400 / 1500: loss 2.457922
# iteration 0 / 1500: loss 939.328739
# iteration 100 / 1500: loss 508.367254
# iteration 200 / 1500: loss 275.713359
# iteration 300 / 1500: loss 150.218989
# iteration 400 / 1500: loss 82.252327
# iteration 500 / 1500: loss 45.450706
# iteration 600 / 1500: loss 25.521346
# iteration 700 / 1500: loss 14.863559
# iteration 800 / 1500: loss 9.105628
# iteration 900 / 1500: loss 5.853557
# iteration 1000 / 1500: loss 4.115357
# iteration 1100 / 1500: loss 3.232824
# iteration 1200 / 1500: loss 2.709296
# iteration 1300 / 1500: loss 2.528286
# iteration 1400 / 1500: loss 2.286109
# iteration 0 / 1500: loss 1041.839137
# iteration 100 / 1500: loss 533.343794
# iteration 200 / 1500: loss 273.881765
# iteration 300 / 1500: loss 141.136948
# iteration 400 / 1500: loss 73.221286
# iteration 500 / 1500: loss 38.577474
# iteration 600 / 1500: loss 20.837440
# iteration 700 / 1500: loss 11.689633
# iteration 800 / 1500: loss 7.041225
# iteration 900 / 1500: loss 4.681441
# iteration 1000 / 1500: loss 3.458491
# iteration 1100 / 1500: loss 2.771601
# iteration 1200 / 1500: loss 2.529241
# iteration 1300 / 1500: loss 2.320751
# iteration 1400 / 1500: loss 2.252066
# iteration 0 / 1500: loss 1097.327840
# iteration 100 / 1500: loss 531.326051
# iteration 200 / 1500: loss 258.063418
# iteration 300 / 1500: loss 125.965303
# iteration 400 / 1500: loss 61.978894
# iteration 500 / 1500: loss 31.182145
# iteration 600 / 1500: loss 16.133151
# iteration 700 / 1500: loss 8.941043
# iteration 800 / 1500: loss 5.463117
# iteration 900 / 1500: loss 3.817539
# iteration 1000 / 1500: loss 2.892726
# iteration 1100 / 1500: loss 2.515435
# iteration 1200 / 1500: loss 2.321046
# iteration 1300 / 1500: loss 2.217053
# iteration 1400 / 1500: loss 2.162496
# iteration 0 / 1500: loss 1214.517331
# iteration 100 / 1500: loss 556.430190
# iteration 200 / 1500: loss 255.582819
# iteration 300 / 1500: loss 118.079400
# iteration 400 / 1500: loss 55.278363
# iteration 500 / 1500: loss 26.410398
# iteration 600 / 1500: loss 13.204006
# iteration 700 / 1500: loss 7.231354
# iteration 800 / 1500: loss 4.444804
# iteration 900 / 1500: loss 3.250857
# iteration 1000 / 1500: loss 2.634885
# iteration 1100 / 1500: loss 2.418316
# iteration 1200 / 1500: loss 2.223781
# iteration 1300 / 1500: loss 2.271833
# iteration 1400 / 1500: loss 2.179645
# iteration 0 / 1500: loss 1295.910328
# iteration 100 / 1500: loss 561.371644
# iteration 200 / 1500: loss 244.088956
# iteration 300 / 1500: loss 106.904112
# iteration 400 / 1500: loss 47.426098
# iteration 500 / 1500: loss 21.682700
# iteration 600 / 1500: loss 10.688265
# iteration 700 / 1500: loss 5.805340
# iteration 800 / 1500: loss 3.765142
# iteration 900 / 1500: loss 2.861126
# iteration 1000 / 1500: loss 2.387541
# iteration 1100 / 1500: loss 2.278227
# iteration 1200 / 1500: loss 2.169792
# iteration 1300 / 1500: loss 2.171773
# iteration 1400 / 1500: loss 2.136040
# iteration 0 / 1500: loss 1376.292709
# iteration 100 / 1500: loss 564.376813
# iteration 200 / 1500: loss 232.215635
# iteration 300 / 1500: loss 96.242404
# iteration 400 / 1500: loss 40.663365
# iteration 500 / 1500: loss 17.941053
# iteration 600 / 1500: loss 8.651636
# iteration 700 / 1500: loss 4.815975
# iteration 800 / 1500: loss 3.241759
# iteration 900 / 1500: loss 2.595963
# iteration 1000 / 1500: loss 2.379873
# iteration 1100 / 1500: loss 2.250151
# iteration 1200 / 1500: loss 2.160276
# iteration 1300 / 1500: loss 2.167384
# iteration 1400 / 1500: loss 2.168733
# iteration 0 / 1500: loss 1422.535344
# iteration 100 / 1500: loss 551.241051
# iteration 200 / 1500: loss 214.699937
# iteration 300 / 1500: loss 84.423772
# iteration 400 / 1500: loss 34.010341
# iteration 500 / 1500: loss 14.490913
# iteration 600 / 1500: loss 6.988716
# iteration 700 / 1500: loss 3.947555
# iteration 800 / 1500: loss 2.874576
# iteration 900 / 1500: loss 2.415610
# iteration 1000 / 1500: loss 2.197427
# iteration 1100 / 1500: loss 2.227058
# iteration 1200 / 1500: loss 2.175135
# iteration 1300 / 1500: loss 2.158990
# iteration 1400 / 1500: loss 2.144010
# iteration 0 / 1500: loss 1531.537781
# iteration 100 / 1500: loss 561.190711
# iteration 200 / 1500: loss 206.829321
# iteration 300 / 1500: loss 77.021007
# iteration 400 / 1500: loss 29.601015
# iteration 500 / 1500: loss 12.253163
# iteration 600 / 1500: loss 5.871171
# iteration 700 / 1500: loss 3.458460
# iteration 800 / 1500: loss 2.607881
# iteration 900 / 1500: loss 2.391171
# iteration 1000 / 1500: loss 2.242962
# iteration 1100 / 1500: loss 2.256599
# iteration 1200 / 1500: loss 2.188022
# iteration 1300 / 1500: loss 2.158987
# iteration 1400 / 1500: loss 2.166318
# iteration 0 / 1500: loss 780.343921
# iteration 100 / 1500: loss 376.973058
# iteration 200 / 1500: loss 183.339134
# iteration 300 / 1500: loss 89.671127
# iteration 400 / 1500: loss 44.515082
# iteration 500 / 1500: loss 22.651205
# iteration 600 / 1500: loss 12.068443
# iteration 700 / 1500: loss 6.847042
# iteration 800 / 1500: loss 4.390286
# iteration 900 / 1500: loss 3.253697
# iteration 1000 / 1500: loss 2.668057
# iteration 1100 / 1500: loss 2.414437
# iteration 1200 / 1500: loss 2.284607
# iteration 1300 / 1500: loss 2.290178
# iteration 1400 / 1500: loss 2.200520
# iteration 0 / 1500: loss 855.772396
# iteration 100 / 1500: loss 382.037449
# iteration 200 / 1500: loss 171.499961
# iteration 300 / 1500: loss 77.730715
# iteration 400 / 1500: loss 35.913075
# iteration 500 / 1500: loss 17.218620
# iteration 600 / 1500: loss 8.880325
# iteration 700 / 1500: loss 5.133471
# iteration 800 / 1500: loss 3.516242
# iteration 900 / 1500: loss 2.712742
# iteration 1000 / 1500: loss 2.378515
# iteration 1100 / 1500: loss 2.256795
# iteration 1200 / 1500: loss 2.165621
# iteration 1300 / 1500: loss 2.106905
# iteration 1400 / 1500: loss 2.171822
# iteration 0 / 1500: loss 945.893627
# iteration 100 / 1500: loss 389.611952
# iteration 200 / 1500: loss 161.473181
# iteration 300 / 1500: loss 67.628455
# iteration 400 / 1500: loss 29.126436
# iteration 500 / 1500: loss 13.176039
# iteration 600 / 1500: loss 6.669000
# iteration 700 / 1500: loss 4.039758
# iteration 800 / 1500: loss 2.890155
# iteration 900 / 1500: loss 2.483714
# iteration 1000 / 1500: loss 2.318104
# iteration 1100 / 1500: loss 2.181753
# iteration 1200 / 1500: loss 2.156914
# iteration 1300 / 1500: loss 2.175945
# iteration 1400 / 1500: loss 2.192818
# iteration 0 / 1500: loss 1033.970453
# iteration 100 / 1500: loss 393.251081
# iteration 200 / 1500: loss 150.512724
# iteration 300 / 1500: loss 58.517218
# iteration 400 / 1500: loss 23.581433
# iteration 500 / 1500: loss 10.326205
# iteration 600 / 1500: loss 5.229264
# iteration 700 / 1500: loss 3.333199
# iteration 800 / 1500: loss 2.566709
# iteration 900 / 1500: loss 2.303373
# iteration 1000 / 1500: loss 2.229190
# iteration 1100 / 1500: loss 2.170154
# iteration 1200 / 1500: loss 2.117148
# iteration 1300 / 1500: loss 2.140452
# iteration 1400 / 1500: loss 2.164017
# iteration 0 / 1500: loss 1110.265905
# iteration 100 / 1500: loss 389.462287
# iteration 200 / 1500: loss 137.691298
# iteration 300 / 1500: loss 49.548487
# iteration 400 / 1500: loss 18.865942
# iteration 500 / 1500: loss 7.947104
# iteration 600 / 1500: loss 4.144398
# iteration 700 / 1500: loss 2.813302
# iteration 800 / 1500: loss 2.393373
# iteration 900 / 1500: loss 2.296878
# iteration 1000 / 1500: loss 2.213305
# iteration 1100 / 1500: loss 2.185593
# iteration 1200 / 1500: loss 2.159438
# iteration 1300 / 1500: loss 2.140747
# iteration 1400 / 1500: loss 2.116068
# iteration 0 / 1500: loss 1209.165067
# iteration 100 / 1500: loss 391.616520
# iteration 200 / 1500: loss 127.928647
# iteration 300 / 1500: loss 42.869264
# iteration 400 / 1500: loss 15.305288
# iteration 500 / 1500: loss 6.377560
# iteration 600 / 1500: loss 3.550433
# iteration 700 / 1500: loss 2.622000
# iteration 800 / 1500: loss 2.236531
# iteration 900 / 1500: loss 2.251493
# iteration 1000 / 1500: loss 2.208646
# iteration 1100 / 1500: loss 2.103910
# iteration 1200 / 1500: loss 2.158959
# iteration 1300 / 1500: loss 2.130036
# iteration 1400 / 1500: loss 2.088200
# iteration 0 / 1500: loss 1288.566666
# iteration 100 / 1500: loss 384.654004
# iteration 200 / 1500: loss 116.196545
# iteration 300 / 1500: loss 36.086296
# iteration 400 / 1500: loss 12.251344
# iteration 500 / 1500: loss 5.184552
# iteration 600 / 1500: loss 3.035196
# iteration 700 / 1500: loss 2.435983
# iteration 800 / 1500: loss 2.292717
# iteration 900 / 1500: loss 2.108425
# iteration 1000 / 1500: loss 2.142672
# iteration 1100 / 1500: loss 2.158981
# iteration 1200 / 1500: loss 2.069374
# iteration 1300 / 1500: loss 2.209168
# iteration 1400 / 1500: loss 2.213084
# iteration 0 / 1500: loss 1372.208030
# iteration 100 / 1500: loss 377.968534
# iteration 200 / 1500: loss 105.427218
# iteration 300 / 1500: loss 30.493117
# iteration 400 / 1500: loss 9.946179
# iteration 500 / 1500: loss 4.322122
# iteration 600 / 1500: loss 2.736525
# iteration 700 / 1500: loss 2.301468
# iteration 800 / 1500: loss 2.156914
# iteration 900 / 1500: loss 2.149181
# iteration 1000 / 1500: loss 2.194061
# iteration 1100 / 1500: loss 2.176548
# iteration 1200 / 1500: loss 2.119742
# iteration 1300 / 1500: loss 2.172333
# iteration 1400 / 1500: loss 2.186150
# iteration 0 / 1500: loss 1455.397520
# iteration 100 / 1500: loss 370.163217
# iteration 200 / 1500: loss 95.470777
# iteration 300 / 1500: loss 25.839465
# iteration 400 / 1500: loss 8.254536
# iteration 500 / 1500: loss 3.696370
# iteration 600 / 1500: loss 2.526206
# iteration 700 / 1500: loss 2.259438
# iteration 800 / 1500: loss 2.223300
# iteration 900 / 1500: loss 2.187733
# iteration 1000 / 1500: loss 2.144415
# iteration 1100 / 1500: loss 2.117227
# iteration 1200 / 1500: loss 2.185496
# iteration 1300 / 1500: loss 2.177829
# iteration 1400 / 1500: loss 2.177310
# iteration 0 / 1500: loss 1540.831101
# iteration 100 / 1500: loss 361.208248
# iteration 200 / 1500: loss 86.176315
# iteration 300 / 1500: loss 21.758969
# iteration 400 / 1500: loss 6.749070
# iteration 500 / 1500: loss 3.244472
# iteration 600 / 1500: loss 2.522264
# iteration 700 / 1500: loss 2.181360
# iteration 800 / 1500: loss 2.203399
# iteration 900 / 1500: loss 2.185178
# iteration 1000 / 1500: loss 2.174458
# iteration 1100 / 1500: loss 2.111204
# iteration 1200 / 1500: loss 2.197300
# iteration 1300 / 1500: loss 2.178293
# iteration 1400 / 1500: loss 2.211451
# iteration 0 / 1500: loss 775.564257
# iteration 100 / 1500: loss 300.414339
# iteration 200 / 1500: loss 117.418765
# iteration 300 / 1500: loss 46.603728
# iteration 400 / 1500: loss 19.395038
# iteration 500 / 1500: loss 8.745498
# iteration 600 / 1500: loss 4.697490
# iteration 700 / 1500: loss 3.096539
# iteration 800 / 1500: loss 2.517660
# iteration 900 / 1500: loss 2.264364
# iteration 1000 / 1500: loss 2.147221
# iteration 1100 / 1500: loss 2.131975
# iteration 1200 / 1500: loss 2.087361
# iteration 1300 / 1500: loss 2.081077
# iteration 1400 / 1500: loss 2.133404
# iteration 0 / 1500: loss 860.017118
# iteration 100 / 1500: loss 299.454602
# iteration 200 / 1500: loss 105.426460
# iteration 300 / 1500: loss 38.169722
# iteration 400 / 1500: loss 14.631049
# iteration 500 / 1500: loss 6.517096
# iteration 600 / 1500: loss 3.708250
# iteration 700 / 1500: loss 2.711051
# iteration 800 / 1500: loss 2.310689
# iteration 900 / 1500: loss 2.250452
# iteration 1000 / 1500: loss 2.160866
# iteration 1100 / 1500: loss 2.110052
# iteration 1200 / 1500: loss 2.100709
# iteration 1300 / 1500: loss 2.094524
# iteration 1400 / 1500: loss 2.147982
# iteration 0 / 1500: loss 932.863679
# iteration 100 / 1500: loss 292.974173
# iteration 200 / 1500: loss 93.036721
# iteration 300 / 1500: loss 30.579075
# iteration 400 / 1500: loss 11.072232
# iteration 500 / 1500: loss 4.898152
# iteration 600 / 1500: loss 2.939401
# iteration 700 / 1500: loss 2.415371
# iteration 800 / 1500: loss 2.207209
# iteration 900 / 1500: loss 2.154279
# iteration 1000 / 1500: loss 2.138327
# iteration 1100 / 1500: loss 2.094751
# iteration 1200 / 1500: loss 2.167531
# iteration 1300 / 1500: loss 2.135193
# iteration 1400 / 1500: loss 2.146640
# iteration 0 / 1500: loss 1010.530364
# iteration 100 / 1500: loss 285.380561
# iteration 200 / 1500: loss 81.859610
# iteration 300 / 1500: loss 24.580101
# iteration 400 / 1500: loss 8.495285
# iteration 500 / 1500: loss 3.898263
# iteration 600 / 1500: loss 2.628074
# iteration 700 / 1500: loss 2.348228
# iteration 800 / 1500: loss 2.151215
# iteration 900 / 1500: loss 2.185076
# iteration 1000 / 1500: loss 2.180905
# iteration 1100 / 1500: loss 2.134976
# iteration 1200 / 1500: loss 2.140528
# iteration 1300 / 1500: loss 2.093787
# iteration 1400 / 1500: loss 2.155413
# iteration 0 / 1500: loss 1116.262700
# iteration 100 / 1500: loss 284.045110
# iteration 200 / 1500: loss 73.457001
# iteration 300 / 1500: loss 20.212390
# iteration 400 / 1500: loss 6.818969
# iteration 500 / 1500: loss 3.342390
# iteration 600 / 1500: loss 2.521803
# iteration 700 / 1500: loss 2.279615
# iteration 800 / 1500: loss 2.274387
# iteration 900 / 1500: loss 2.222073
# iteration 1000 / 1500: loss 2.144457
# iteration 1100 / 1500: loss 2.219277
# iteration 1200 / 1500: loss 2.201497
# iteration 1300 / 1500: loss 2.120013
# iteration 1400 / 1500: loss 2.122434
# iteration 0 / 1500: loss 1201.943059
# iteration 100 / 1500: loss 275.470649
# iteration 200 / 1500: loss 64.405272
# iteration 300 / 1500: loss 16.406080
# iteration 400 / 1500: loss 5.428938
# iteration 500 / 1500: loss 2.855290
# iteration 600 / 1500: loss 2.313114
# iteration 700 / 1500: loss 2.211212
# iteration 800 / 1500: loss 2.098980
# iteration 900 / 1500: loss 2.139558
# iteration 1000 / 1500: loss 2.178396
# iteration 1100 / 1500: loss 2.179346
# iteration 1200 / 1500: loss 2.163281
# iteration 1300 / 1500: loss 2.161799
# iteration 1400 / 1500: loss 2.113202
# iteration 0 / 1500: loss 1282.374396
# iteration 100 / 1500: loss 263.930369
# iteration 200 / 1500: loss 55.843801
# iteration 300 / 1500: loss 13.133710
# iteration 400 / 1500: loss 4.333988
# iteration 500 / 1500: loss 2.577284
# iteration 600 / 1500: loss 2.217650
# iteration 700 / 1500: loss 2.214811
# iteration 800 / 1500: loss 2.142680
# iteration 900 / 1500: loss 2.211617
# iteration 1000 / 1500: loss 2.172395
# iteration 1100 / 1500: loss 2.094432
# iteration 1200 / 1500: loss 2.189424
# iteration 1300 / 1500: loss 2.152751
# iteration 1400 / 1500: loss 2.155245
# iteration 0 / 1500: loss 1372.932750
# iteration 100 / 1500: loss 254.630408
# iteration 200 / 1500: loss 48.716524
# iteration 300 / 1500: loss 10.728272
# iteration 400 / 1500: loss 3.769811
# iteration 500 / 1500: loss 2.402689
# iteration 600 / 1500: loss 2.188528
# iteration 700 / 1500: loss 2.139381
# iteration 800 / 1500: loss 2.166673
# iteration 900 / 1500: loss 2.112811
# iteration 1000 / 1500: loss 2.113717
# iteration 1100 / 1500: loss 2.205309
# iteration 1200 / 1500: loss 2.196148
# iteration 1300 / 1500: loss 2.161673
# iteration 1400 / 1500: loss 2.108699
# iteration 0 / 1500: loss 1480.414342
# iteration 100 / 1500: loss 246.563073
# iteration 200 / 1500: loss 42.722067
# iteration 300 / 1500: loss 8.846615
# iteration 400 / 1500: loss 3.325495
# iteration 500 / 1500: loss 2.358667
# iteration 600 / 1500: loss 2.229260
# iteration 700 / 1500: loss 2.133027
# iteration 800 / 1500: loss 2.091101
# iteration 900 / 1500: loss 2.153557
# iteration 1000 / 1500: loss 2.175001
# iteration 1100 / 1500: loss 2.170348
# iteration 1200 / 1500: loss 2.174262
# iteration 1300 / 1500: loss 2.175945
# iteration 1400 / 1500: loss 2.140189
# iteration 0 / 1500: loss 1548.235490
# iteration 100 / 1500: loss 232.424851
# iteration 200 / 1500: loss 36.516069
# iteration 300 / 1500: loss 7.393689
# iteration 400 / 1500: loss 2.913291
# iteration 500 / 1500: loss 2.264145
# iteration 600 / 1500: loss 2.219044
# iteration 700 / 1500: loss 2.209667
# iteration 800 / 1500: loss 2.205289
# iteration 900 / 1500: loss 2.121032
# iteration 1000 / 1500: loss 2.205385
# iteration 1100 / 1500: loss 2.142084
# iteration 1200 / 1500: loss 2.211014
# iteration 1300 / 1500: loss 2.139363
# iteration 1400 / 1500: loss 2.236333
# iteration 0 / 1500: loss 772.367424
# iteration 100 / 1500: loss 239.488911
# iteration 200 / 1500: loss 75.466345
# iteration 300 / 1500: loss 24.755051
# iteration 400 / 1500: loss 9.084717
# iteration 500 / 1500: loss 4.380209
# iteration 600 / 1500: loss 2.872749
# iteration 700 / 1500: loss 2.328190
# iteration 800 / 1500: loss 2.171135
# iteration 900 / 1500: loss 2.167970
# iteration 1000 / 1500: loss 2.130015
# iteration 1100 / 1500: loss 2.160474
# iteration 1200 / 1500: loss 2.112900
# iteration 1300 / 1500: loss 2.117656
# iteration 1400 / 1500: loss 2.115007
# iteration 0 / 1500: loss 850.451076
# iteration 100 / 1500: loss 231.186625
# iteration 200 / 1500: loss 64.227728
# iteration 300 / 1500: loss 19.041575
# iteration 400 / 1500: loss 6.628858
# iteration 500 / 1500: loss 3.345262
# iteration 600 / 1500: loss 2.457010
# iteration 700 / 1500: loss 2.321087
# iteration 800 / 1500: loss 2.125634
# iteration 900 / 1500: loss 2.116325
# iteration 1000 / 1500: loss 2.124711
# iteration 1100 / 1500: loss 2.081739
# iteration 1200 / 1500: loss 2.078586
# iteration 1300 / 1500: loss 2.122725
# iteration 1400 / 1500: loss 2.097913
# iteration 0 / 1500: loss 964.943982
# iteration 100 / 1500: loss 230.428739
# iteration 200 / 1500: loss 56.506981
# iteration 300 / 1500: loss 15.044772
# iteration 400 / 1500: loss 5.214832
# iteration 500 / 1500: loss 2.849931
# iteration 600 / 1500: loss 2.251948
# iteration 700 / 1500: loss 2.207957
# iteration 800 / 1500: loss 2.147100
# iteration 900 / 1500: loss 2.158943
# iteration 1000 / 1500: loss 2.179037
# iteration 1100 / 1500: loss 2.095857
# iteration 1200 / 1500: loss 2.104154
# iteration 1300 / 1500: loss 2.080130
# iteration 1400 / 1500: loss 2.084921
# iteration 0 / 1500: loss 1033.407487
# iteration 100 / 1500: loss 216.942013
# iteration 200 / 1500: loss 46.994784
# iteration 300 / 1500: loss 11.507490
# iteration 400 / 1500: loss 4.091056
# iteration 500 / 1500: loss 2.543698
# iteration 600 / 1500: loss 2.236508
# iteration 700 / 1500: loss 2.165637
# iteration 800 / 1500: loss 2.127151
# iteration 900 / 1500: loss 2.193160
# iteration 1000 / 1500: loss 2.165832
# iteration 1100 / 1500: loss 2.104032
# iteration 1200 / 1500: loss 2.204586
# iteration 1300 / 1500: loss 2.182890
# iteration 1400 / 1500: loss 2.028318
# iteration 0 / 1500: loss 1112.526281
# iteration 100 / 1500: loss 205.047753
# iteration 200 / 1500: loss 39.325528
# iteration 300 / 1500: loss 8.920273
# iteration 400 / 1500: loss 3.462577
# iteration 500 / 1500: loss 2.379037
# iteration 600 / 1500: loss 2.225991
# iteration 700 / 1500: loss 2.112201
# iteration 800 / 1500: loss 2.143914
# iteration 900 / 1500: loss 2.174293
# iteration 1000 / 1500: loss 2.170663
# iteration 1100 / 1500: loss 2.185267
# iteration 1200 / 1500: loss 2.198957
# iteration 1300 / 1500: loss 2.199691
# iteration 1400 / 1500: loss 2.158830
# iteration 0 / 1500: loss 1190.000371
# iteration 100 / 1500: loss 192.642143
# iteration 200 / 1500: loss 32.760680
# iteration 300 / 1500: loss 7.086535
# iteration 400 / 1500: loss 2.948306
# iteration 500 / 1500: loss 2.294316
# iteration 600 / 1500: loss 2.146389
# iteration 700 / 1500: loss 2.159037
# iteration 800 / 1500: loss 2.160648
# iteration 900 / 1500: loss 2.173867
# iteration 1000 / 1500: loss 2.110957
# iteration 1100 / 1500: loss 2.164850
# iteration 1200 / 1500: loss 2.146123
# iteration 1300 / 1500: loss 2.098924
# iteration 1400 / 1500: loss 2.114068
# iteration 0 / 1500: loss 1291.070113
# iteration 100 / 1500: loss 183.292224
# iteration 200 / 1500: loss 27.720580
# iteration 300 / 1500: loss 5.851140
# iteration 400 / 1500: loss 2.648004
# iteration 500 / 1500: loss 2.247587
# iteration 600 / 1500: loss 2.171692
# iteration 700 / 1500: loss 2.153156
# iteration 800 / 1500: loss 2.126296
# iteration 900 / 1500: loss 2.134764
# iteration 1000 / 1500: loss 2.126502
# iteration 1100 / 1500: loss 2.136632
# iteration 1200 / 1500: loss 2.176100
# iteration 1300 / 1500: loss 2.132048
# iteration 1400 / 1500: loss 2.123847
# iteration 0 / 1500: loss 1375.054629
# iteration 100 / 1500: loss 171.681091
# iteration 200 / 1500: loss 23.153306
# iteration 300 / 1500: loss 4.771740
# iteration 400 / 1500: loss 2.454955
# iteration 500 / 1500: loss 2.235278
# iteration 600 / 1500: loss 2.171326
# iteration 700 / 1500: loss 2.132637
# iteration 800 / 1500: loss 2.213278
# iteration 900 / 1500: loss 2.154249
# iteration 1000 / 1500: loss 2.133730
# iteration 1100 / 1500: loss 2.192045
# iteration 1200 / 1500: loss 2.202153
# iteration 1300 / 1500: loss 2.147004
# iteration 1400 / 1500: loss 2.175568
# iteration 0 / 1500: loss 1475.055224
# iteration 100 / 1500: loss 161.494682
# iteration 200 / 1500: loss 19.482061
# iteration 300 / 1500: loss 4.045800
# iteration 400 / 1500: loss 2.377011
# iteration 500 / 1500: loss 2.165497
# iteration 600 / 1500: loss 2.141881
# iteration 700 / 1500: loss 2.170538
# iteration 800 / 1500: loss 2.109715
# iteration 900 / 1500: loss 2.141797
# iteration 1000 / 1500: loss 2.181071
# iteration 1100 / 1500: loss 2.194863
# iteration 1200 / 1500: loss 2.115535
# iteration 1300 / 1500: loss 2.156435
# iteration 1400 / 1500: loss 2.178651
# iteration 0 / 1500: loss 1563.056437
# iteration 100 / 1500: loss 150.362379
# iteration 200 / 1500: loss 16.281687
# iteration 300 / 1500: loss 3.546331
# iteration 400 / 1500: loss 2.287983
# iteration 500 / 1500: loss 2.175298
# iteration 600 / 1500: loss 2.174613
# iteration 700 / 1500: loss 2.131917
# iteration 800 / 1500: loss 2.189290
# iteration 900 / 1500: loss 2.186572
# iteration 1000 / 1500: loss 2.151687
# iteration 1100 / 1500: loss 2.196387
# iteration 1200 / 1500: loss 2.123644
# iteration 1300 / 1500: loss 2.180165
# iteration 1400 / 1500: loss 2.140260
# iteration 0 / 1500: loss 765.868769
# iteration 100 / 1500: loss 189.933082
# iteration 200 / 1500: loss 48.366060
# iteration 300 / 1500: loss 13.554247
# iteration 400 / 1500: loss 5.004809
# iteration 500 / 1500: loss 2.856598
# iteration 600 / 1500: loss 2.223810
# iteration 700 / 1500: loss 2.169615
# iteration 800 / 1500: loss 2.135762
# iteration 900 / 1500: loss 2.119180
# iteration 1000 / 1500: loss 2.149502
# iteration 1100 / 1500: loss 2.111265
# iteration 1200 / 1500: loss 2.122332
# iteration 1300 / 1500: loss 2.133286
# iteration 1400 / 1500: loss 2.220339
# iteration 0 / 1500: loss 858.208259
# iteration 100 / 1500: loss 182.285646
# iteration 200 / 1500: loss 40.140071
# iteration 300 / 1500: loss 10.225720
# iteration 400 / 1500: loss 3.885157
# iteration 500 / 1500: loss 2.440845
# iteration 600 / 1500: loss 2.175081
# iteration 700 / 1500: loss 2.209640
# iteration 800 / 1500: loss 2.117427
# iteration 900 / 1500: loss 2.036232
# iteration 1000 / 1500: loss 2.213978
# iteration 1100 / 1500: loss 2.041859
# iteration 1200 / 1500: loss 2.132248
# iteration 1300 / 1500: loss 2.075920
# iteration 1400 / 1500: loss 2.117758
# iteration 0 / 1500: loss 943.973411
# iteration 100 / 1500: loss 171.911067
# iteration 200 / 1500: loss 32.906893
# iteration 300 / 1500: loss 7.663613
# iteration 400 / 1500: loss 3.163465
# iteration 500 / 1500: loss 2.322541
# iteration 600 / 1500: loss 2.153983
# iteration 700 / 1500: loss 2.103706
# iteration 800 / 1500: loss 2.184503
# iteration 900 / 1500: loss 2.169821
# iteration 1000 / 1500: loss 2.107168
# iteration 1100 / 1500: loss 2.158807
# iteration 1200 / 1500: loss 2.138186
# iteration 1300 / 1500: loss 2.130389
# iteration 1400 / 1500: loss 2.166008
# iteration 0 / 1500: loss 1034.310487
# iteration 100 / 1500: loss 161.295345
# iteration 200 / 1500: loss 26.703581
# iteration 300 / 1500: loss 5.938544
# iteration 400 / 1500: loss 2.718578
# iteration 500 / 1500: loss 2.199051
# iteration 600 / 1500: loss 2.101440
# iteration 700 / 1500: loss 2.164148
# iteration 800 / 1500: loss 2.126552
# iteration 900 / 1500: loss 2.274317
# iteration 1000 / 1500: loss 2.179967
# iteration 1100 / 1500: loss 2.082254
# iteration 1200 / 1500: loss 2.117327
# iteration 1300 / 1500: loss 2.180701
# iteration 1400 / 1500: loss 2.147970
# iteration 0 / 1500: loss 1131.795198
# iteration 100 / 1500: loss 151.141548
# iteration 200 / 1500: loss 21.877299
# iteration 300 / 1500: loss 4.762487
# iteration 400 / 1500: loss 2.449332
# iteration 500 / 1500: loss 2.228962
# iteration 600 / 1500: loss 2.139760
# iteration 700 / 1500: loss 2.121401
# iteration 800 / 1500: loss 2.058276
# iteration 900 / 1500: loss 2.100517
# iteration 1000 / 1500: loss 2.143780
# iteration 1100 / 1500: loss 2.095087
# iteration 1200 / 1500: loss 2.157766
# iteration 1300 / 1500: loss 2.163006
# iteration 1400 / 1500: loss 2.150265
# iteration 0 / 1500: loss 1196.740511
# iteration 100 / 1500: loss 137.056433
# iteration 200 / 1500: loss 17.471689
# iteration 300 / 1500: loss 3.862249
# iteration 400 / 1500: loss 2.382278
# iteration 500 / 1500: loss 2.129257
# iteration 600 / 1500: loss 2.087415
# iteration 700 / 1500: loss 2.169187
# iteration 800 / 1500: loss 2.136363
# iteration 900 / 1500: loss 2.146749
# iteration 1000 / 1500: loss 2.157961
# iteration 1100 / 1500: loss 2.195646
# iteration 1200 / 1500: loss 2.134355
# iteration 1300 / 1500: loss 2.147493
# iteration 1400 / 1500: loss 2.147271
# iteration 0 / 1500: loss 1285.890265
# iteration 100 / 1500: loss 126.163143
# iteration 200 / 1500: loss 14.245446
# iteration 300 / 1500: loss 3.342526
# iteration 400 / 1500: loss 2.323592
# iteration 500 / 1500: loss 2.125743
# iteration 600 / 1500: loss 2.234377
# iteration 700 / 1500: loss 2.145687
# iteration 800 / 1500: loss 2.168013
# iteration 900 / 1500: loss 2.163022
# iteration 1000 / 1500: loss 2.108873
# iteration 1100 / 1500: loss 2.168502
# iteration 1200 / 1500: loss 2.087039
# iteration 1300 / 1500: loss 2.166722
# iteration 1400 / 1500: loss 2.207268
# iteration 0 / 1500: loss 1383.615497
# iteration 100 / 1500: loss 116.558623
# iteration 200 / 1500: loss 11.616162
# iteration 300 / 1500: loss 3.012888
# iteration 400 / 1500: loss 2.243046
# iteration 500 / 1500: loss 2.149931
# iteration 600 / 1500: loss 2.186583
# iteration 700 / 1500: loss 2.201068
# iteration 800 / 1500: loss 2.155112
# iteration 900 / 1500: loss 2.133530
# iteration 1000 / 1500: loss 2.180170
# iteration 1100 / 1500: loss 2.183353
# iteration 1200 / 1500: loss 2.120090
# iteration 1300 / 1500: loss 2.248619
# iteration 1400 / 1500: loss 2.180560
# iteration 0 / 1500: loss 1469.423059
# iteration 100 / 1500: loss 105.876037
# iteration 200 / 1500: loss 9.535338
# iteration 300 / 1500: loss 2.676475
# iteration 400 / 1500: loss 2.253008
# iteration 500 / 1500: loss 2.170863
# iteration 600 / 1500: loss 2.178510
# iteration 700 / 1500: loss 2.168183
# iteration 800 / 1500: loss 2.129960
# iteration 900 / 1500: loss 2.182896
# iteration 1000 / 1500: loss 2.202105
# iteration 1100 / 1500: loss 2.188643
# iteration 1200 / 1500: loss 2.132975
# iteration 1300 / 1500: loss 2.183895
# iteration 1400 / 1500: loss 2.180846
# iteration 0 / 1500: loss 1529.482650
# iteration 100 / 1500: loss 94.550376
# iteration 200 / 1500: loss 7.719409
# iteration 300 / 1500: loss 2.528840
# iteration 400 / 1500: loss 2.201324
# iteration 500 / 1500: loss 2.150939
# iteration 600 / 1500: loss 2.140894
# iteration 700 / 1500: loss 2.202518
# iteration 800 / 1500: loss 2.183163
# iteration 900 / 1500: loss 2.170879
# iteration 1000 / 1500: loss 2.137035
# iteration 1100 / 1500: loss 2.192082
# iteration 1200 / 1500: loss 2.234791
# iteration 1300 / 1500: loss 2.157749
# iteration 1400 / 1500: loss 2.197844
# iteration 0 / 1500: loss 780.171039
# iteration 100 / 1500: loss 154.626803
# iteration 200 / 1500: loss 32.158782
# iteration 300 / 1500: loss 8.148998
# iteration 400 / 1500: loss 3.341399
# iteration 500 / 1500: loss 2.301296
# iteration 600 / 1500: loss 2.133769
# iteration 700 / 1500: loss 2.047229
# iteration 800 / 1500: loss 2.106297
# iteration 900 / 1500: loss 2.154128
# iteration 1000 / 1500: loss 2.170019
# iteration 1100 / 1500: loss 2.131140
# iteration 1200 / 1500: loss 2.056061
# iteration 1300 / 1500: loss 2.066322
# iteration 1400 / 1500: loss 2.219525
# iteration 0 / 1500: loss 855.117372
# iteration 100 / 1500: loss 141.892577
# iteration 200 / 1500: loss 25.093630
# iteration 300 / 1500: loss 5.972094
# iteration 400 / 1500: loss 2.699484
# iteration 500 / 1500: loss 2.221102
# iteration 600 / 1500: loss 2.108806
# iteration 700 / 1500: loss 2.119663
# iteration 800 / 1500: loss 2.067851
# iteration 900 / 1500: loss 2.073482
# iteration 1000 / 1500: loss 2.106618
# iteration 1100 / 1500: loss 2.112477
# iteration 1200 / 1500: loss 2.128450
# iteration 1300 / 1500: loss 2.113105
# iteration 1400 / 1500: loss 2.067871
# iteration 0 / 1500: loss 940.510346
# iteration 100 / 1500: loss 130.515760
# iteration 200 / 1500: loss 19.773065
# iteration 300 / 1500: loss 4.549986
# iteration 400 / 1500: loss 2.496074
# iteration 500 / 1500: loss 2.173382
# iteration 600 / 1500: loss 2.195994
# iteration 700 / 1500: loss 2.169618
# iteration 800 / 1500: loss 2.154080
# iteration 900 / 1500: loss 2.154101
# iteration 1000 / 1500: loss 2.180335
# iteration 1100 / 1500: loss 2.203914
# iteration 1200 / 1500: loss 2.152616
# iteration 1300 / 1500: loss 2.092513
# iteration 1400 / 1500: loss 2.140778
# iteration 0 / 1500: loss 1017.972904
# iteration 100 / 1500: loss 118.079927
# iteration 200 / 1500: loss 15.447189
# iteration 300 / 1500: loss 3.671097
# iteration 400 / 1500: loss 2.319722
# iteration 500 / 1500: loss 2.170979
# iteration 600 / 1500: loss 2.113059
# iteration 700 / 1500: loss 2.149867
# iteration 800 / 1500: loss 2.145461
# iteration 900 / 1500: loss 2.115497
# iteration 1000 / 1500: loss 2.148938
# iteration 1100 / 1500: loss 2.160709
# iteration 1200 / 1500: loss 2.123334
# iteration 1300 / 1500: loss 2.183524
# iteration 1400 / 1500: loss 2.182068
# iteration 0 / 1500: loss 1099.463854
# iteration 100 / 1500: loss 106.817649
# iteration 200 / 1500: loss 12.183087
# iteration 300 / 1500: loss 3.055039
# iteration 400 / 1500: loss 2.170326
# iteration 500 / 1500: loss 2.186106
# iteration 600 / 1500: loss 2.239907
# iteration 700 / 1500: loss 2.130601
# iteration 800 / 1500: loss 2.159369
# iteration 900 / 1500: loss 2.127118
# iteration 1000 / 1500: loss 2.237390
# iteration 1100 / 1500: loss 2.122002
# iteration 1200 / 1500: loss 2.132525
# iteration 1300 / 1500: loss 2.192195
# iteration 1400 / 1500: loss 2.080846
# iteration 0 / 1500: loss 1192.725786
# iteration 100 / 1500: loss 96.807589
# iteration 200 / 1500: loss 9.771524
# iteration 300 / 1500: loss 2.761200
# iteration 400 / 1500: loss 2.187920
# iteration 500 / 1500: loss 2.141700
# iteration 600 / 1500: loss 2.148851
# iteration 700 / 1500: loss 2.156558
# iteration 800 / 1500: loss 2.086203
# iteration 900 / 1500: loss 2.227255
# iteration 1000 / 1500: loss 2.198792
# iteration 1100 / 1500: loss 2.154304
# iteration 1200 / 1500: loss 2.241188
# iteration 1300 / 1500: loss 2.152828
# iteration 1400 / 1500: loss 2.139712
# iteration 0 / 1500: loss 1299.124112
# iteration 100 / 1500: loss 88.208221
# iteration 200 / 1500: loss 7.857829
# iteration 300 / 1500: loss 2.552903
# iteration 400 / 1500: loss 2.242719
# iteration 500 / 1500: loss 2.158198
# iteration 600 / 1500: loss 2.142479
# iteration 700 / 1500: loss 2.161192
# iteration 800 / 1500: loss 2.195142
# iteration 900 / 1500: loss 2.185826
# iteration 1000 / 1500: loss 2.132235
# iteration 1100 / 1500: loss 2.224559
# iteration 1200 / 1500: loss 2.123244
# iteration 1300 / 1500: loss 2.145580
# iteration 1400 / 1500: loss 2.189706
# iteration 0 / 1500: loss 1367.560167
# iteration 100 / 1500: loss 77.698097
# iteration 200 / 1500: loss 6.345702
# iteration 300 / 1500: loss 2.450546
# iteration 400 / 1500: loss 2.217013
# iteration 500 / 1500: loss 2.131110
# iteration 600 / 1500: loss 2.156488
# iteration 700 / 1500: loss 2.140095
# iteration 800 / 1500: loss 2.163615
# iteration 900 / 1500: loss 2.201825
# iteration 1000 / 1500: loss 2.202039
# iteration 1100 / 1500: loss 2.132685
# iteration 1200 / 1500: loss 2.170914
# iteration 1300 / 1500: loss 2.210339
# iteration 1400 / 1500: loss 2.156362
# iteration 0 / 1500: loss 1466.661446
# iteration 100 / 1500: loss 69.707195
# iteration 200 / 1500: loss 5.265696
# iteration 300 / 1500: loss 2.302956
# iteration 400 / 1500: loss 2.174792
# iteration 500 / 1500: loss 2.175081
# iteration 600 / 1500: loss 2.163350
# iteration 700 / 1500: loss 2.182340
# iteration 800 / 1500: loss 2.196896
# iteration 900 / 1500: loss 2.161220
# iteration 1000 / 1500: loss 2.133927
# iteration 1100 / 1500: loss 2.161739
# iteration 1200 / 1500: loss 2.054843
# iteration 1300 / 1500: loss 2.149336
# iteration 1400 / 1500: loss 2.159228
# iteration 0 / 1500: loss 1545.587406
# iteration 100 / 1500: loss 61.644354
# iteration 200 / 1500: loss 4.451757
# iteration 300 / 1500: loss 2.264451
# iteration 400 / 1500: loss 2.158871
# iteration 500 / 1500: loss 2.172427
# iteration 600 / 1500: loss 2.163150
# iteration 700 / 1500: loss 2.142875
# iteration 800 / 1500: loss 2.133435
# iteration 900 / 1500: loss 2.219674
# iteration 1000 / 1500: loss 2.176825
# iteration 1100 / 1500: loss 2.168183
# iteration 1200 / 1500: loss 2.168096
# iteration 1300 / 1500: loss 2.167807
# iteration 1400 / 1500: loss 2.208373
# iteration 0 / 1500: loss 768.935250
# iteration 100 / 1500: loss 122.349807
# iteration 200 / 1500: loss 21.007665
# iteration 300 / 1500: loss 5.026502
# iteration 400 / 1500: loss 2.525313
# iteration 500 / 1500: loss 2.210829
# iteration 600 / 1500: loss 2.150360
# iteration 700 / 1500: loss 2.089389
# iteration 800 / 1500: loss 2.070949
# iteration 900 / 1500: loss 2.174843
# iteration 1000 / 1500: loss 2.216498
# iteration 1100 / 1500: loss 2.110748
# iteration 1200 / 1500: loss 2.151443
# iteration 1300 / 1500: loss 2.150833
# iteration 1400 / 1500: loss 2.161543
# iteration 0 / 1500: loss 856.465743
# iteration 100 / 1500: loss 111.427304
# iteration 200 / 1500: loss 16.116628
# iteration 300 / 1500: loss 3.900157
# iteration 400 / 1500: loss 2.394629
# iteration 500 / 1500: loss 2.155448
# iteration 600 / 1500: loss 2.124317
# iteration 700 / 1500: loss 2.067127
# iteration 800 / 1500: loss 2.129166
# iteration 900 / 1500: loss 2.129776
# iteration 1000 / 1500: loss 2.115620
# iteration 1100 / 1500: loss 2.078874
# iteration 1200 / 1500: loss 2.109880
# iteration 1300 / 1500: loss 2.073958
# iteration 1400 / 1500: loss 2.241146
# iteration 0 / 1500: loss 951.217854
# iteration 100 / 1500: loss 100.763112
# iteration 200 / 1500: loss 12.443908
# iteration 300 / 1500: loss 3.217706
# iteration 400 / 1500: loss 2.228585
# iteration 500 / 1500: loss 2.170120
# iteration 600 / 1500: loss 2.108308
# iteration 700 / 1500: loss 2.166820
# iteration 800 / 1500: loss 2.085777
# iteration 900 / 1500: loss 2.196209
# iteration 1000 / 1500: loss 2.164067
# iteration 1100 / 1500: loss 2.156080
# iteration 1200 / 1500: loss 2.091517
# iteration 1300 / 1500: loss 2.110841
# iteration 1400 / 1500: loss 2.157909
# iteration 0 / 1500: loss 1037.519343
# iteration 100 / 1500: loss 89.769001
# iteration 200 / 1500: loss 9.522212
# iteration 300 / 1500: loss 2.795925
# iteration 400 / 1500: loss 2.177554
# iteration 500 / 1500: loss 2.181808
# iteration 600 / 1500: loss 2.090347
# iteration 700 / 1500: loss 2.120685
# iteration 800 / 1500: loss 2.143929
# iteration 900 / 1500: loss 2.190787
# iteration 1000 / 1500: loss 2.126948
# iteration 1100 / 1500: loss 2.150599
# iteration 1200 / 1500: loss 2.114548
# iteration 1300 / 1500: loss 2.171706
# iteration 1400 / 1500: loss 2.084904
# iteration 0 / 1500: loss 1108.183362
# iteration 100 / 1500: loss 78.370445
# iteration 200 / 1500: loss 7.385391
# iteration 300 / 1500: loss 2.535247
# iteration 400 / 1500: loss 2.141667
# iteration 500 / 1500: loss 2.093110
# iteration 600 / 1500: loss 2.129261
# iteration 700 / 1500: loss 2.217130
# iteration 800 / 1500: loss 2.119883
# iteration 900 / 1500: loss 2.136062
# iteration 1000 / 1500: loss 2.188658
# iteration 1100 / 1500: loss 2.135138
# iteration 1200 / 1500: loss 2.122958
# iteration 1300 / 1500: loss 2.186015
# iteration 1400 / 1500: loss 2.163611
# iteration 0 / 1500: loss 1194.006196
# iteration 100 / 1500: loss 68.901238
# iteration 200 / 1500: loss 5.905275
# iteration 300 / 1500: loss 2.345734
# iteration 400 / 1500: loss 2.155580
# iteration 500 / 1500: loss 2.185791
# iteration 600 / 1500: loss 2.174318
# iteration 700 / 1500: loss 2.116333
# iteration 800 / 1500: loss 2.189036
# iteration 900 / 1500: loss 2.149946
# iteration 1000 / 1500: loss 2.186845
# iteration 1100 / 1500: loss 2.124339
# iteration 1200 / 1500: loss 2.120420
# iteration 1300 / 1500: loss 2.216800
# iteration 1400 / 1500: loss 2.181169
# iteration 0 / 1500: loss 1293.483938
# iteration 100 / 1500: loss 61.004742
# iteration 200 / 1500: loss 4.829140
# iteration 300 / 1500: loss 2.269394
# iteration 400 / 1500: loss 2.173382
# iteration 500 / 1500: loss 2.186286
# iteration 600 / 1500: loss 2.165642
# iteration 700 / 1500: loss 2.119235
# iteration 800 / 1500: loss 2.100727
# iteration 900 / 1500: loss 2.214911
# iteration 1000 / 1500: loss 2.172128
# iteration 1100 / 1500: loss 2.198952
# iteration 1200 / 1500: loss 2.137472
# iteration 1300 / 1500: loss 2.173600
# iteration 1400 / 1500: loss 2.160422
# iteration 0 / 1500: loss 1390.456096
# iteration 100 / 1500: loss 53.652537
# iteration 200 / 1500: loss 4.067112
# iteration 300 / 1500: loss 2.245591
# iteration 400 / 1500: loss 2.165600
# iteration 500 / 1500: loss 2.227592
# iteration 600 / 1500: loss 2.139139
# iteration 700 / 1500: loss 2.139519
# iteration 800 / 1500: loss 2.146445
# iteration 900 / 1500: loss 2.150052
# iteration 1000 / 1500: loss 2.136980
# iteration 1100 / 1500: loss 2.130794
# iteration 1200 / 1500: loss 2.172192
# iteration 1300 / 1500: loss 2.141158
# iteration 1400 / 1500: loss 2.181868
# iteration 0 / 1500: loss 1457.833678
# iteration 100 / 1500: loss 45.979858
# iteration 200 / 1500: loss 3.431732
# iteration 300 / 1500: loss 2.230545
# iteration 400 / 1500: loss 2.152543
# iteration 500 / 1500: loss 2.124270
# iteration 600 / 1500: loss 2.159422
# iteration 700 / 1500: loss 2.134457
# iteration 800 / 1500: loss 2.191879
# iteration 900 / 1500: loss 2.109098
# iteration 1000 / 1500: loss 2.221957
# iteration 1100 / 1500: loss 2.143166
# iteration 1200 / 1500: loss 2.194078
# iteration 1300 / 1500: loss 2.206817
# iteration 1400 / 1500: loss 2.179574
# iteration 0 / 1500: loss 1530.737331
# iteration 100 / 1500: loss 39.509220
# iteration 200 / 1500: loss 3.098149
# iteration 300 / 1500: loss 2.172903
# iteration 400 / 1500: loss 2.148534
# iteration 500 / 1500: loss 2.183680
# iteration 600 / 1500: loss 2.168019
# iteration 700 / 1500: loss 2.196665
# iteration 800 / 1500: loss 2.254576
# iteration 900 / 1500: loss 2.135775
# iteration 1000 / 1500: loss 2.165032
# iteration 1100 / 1500: loss 2.215833
# iteration 1200 / 1500: loss 2.211561
# iteration 1300 / 1500: loss 2.178649
# iteration 1400 / 1500: loss 2.109144
# iteration 0 / 1500: loss 776.321603
# iteration 100 / 1500: loss 99.004683
# iteration 200 / 1500: loss 14.315352
# iteration 300 / 1500: loss 3.654750
# iteration 400 / 1500: loss 2.307890
# iteration 500 / 1500: loss 2.191644
# iteration 600 / 1500: loss 2.086010
# iteration 700 / 1500: loss 2.082107
# iteration 800 / 1500: loss 2.101411
# iteration 900 / 1500: loss 2.172393
# iteration 1000 / 1500: loss 2.073028
# iteration 1100 / 1500: loss 2.139464
# iteration 1200 / 1500: loss 2.133498
# iteration 1300 / 1500: loss 2.158297
# iteration 1400 / 1500: loss 2.137765
# iteration 0 / 1500: loss 867.282198
# iteration 100 / 1500: loss 88.000059
# iteration 200 / 1500: loss 10.697861
# iteration 300 / 1500: loss 3.029930
# iteration 400 / 1500: loss 2.223131
# iteration 500 / 1500: loss 2.156566
# iteration 600 / 1500: loss 2.197623
# iteration 700 / 1500: loss 2.178097
# iteration 800 / 1500: loss 2.135597
# iteration 900 / 1500: loss 2.183691
# iteration 1000 / 1500: loss 2.078216
# iteration 1100 / 1500: loss 2.108194
# iteration 1200 / 1500: loss 2.153485
# iteration 1300 / 1500: loss 2.162484
# iteration 1400 / 1500: loss 2.134468
# iteration 0 / 1500: loss 942.292403
# iteration 100 / 1500: loss 76.380751
# iteration 200 / 1500: loss 8.084368
# iteration 300 / 1500: loss 2.563910
# iteration 400 / 1500: loss 2.142246
# iteration 500 / 1500: loss 2.158035
# iteration 600 / 1500: loss 2.115934
# iteration 700 / 1500: loss 2.187044
# iteration 800 / 1500: loss 2.168557
# iteration 900 / 1500: loss 2.115184
# iteration 1000 / 1500: loss 2.131158
# iteration 1100 / 1500: loss 2.133178
# iteration 1200 / 1500: loss 2.162510
# iteration 1300 / 1500: loss 2.119129
# iteration 1400 / 1500: loss 2.150095
# iteration 0 / 1500: loss 1030.393347
# iteration 100 / 1500: loss 66.457730
# iteration 200 / 1500: loss 6.236572
# iteration 300 / 1500: loss 2.351582
# iteration 400 / 1500: loss 2.158845
# iteration 500 / 1500: loss 2.199643
# iteration 600 / 1500: loss 2.176307
# iteration 700 / 1500: loss 2.186785
# iteration 800 / 1500: loss 2.173781
# iteration 900 / 1500: loss 2.127882
# iteration 1000 / 1500: loss 2.159246
# iteration 1100 / 1500: loss 2.154182
# iteration 1200 / 1500: loss 2.115420
# iteration 1300 / 1500: loss 2.119524
# iteration 1400 / 1500: loss 2.115271
# iteration 0 / 1500: loss 1104.401239
# iteration 100 / 1500: loss 57.020572
# iteration 200 / 1500: loss 4.850969
# iteration 300 / 1500: loss 2.288693
# iteration 400 / 1500: loss 2.085619
# iteration 500 / 1500: loss 2.074319
# iteration 600 / 1500: loss 2.121708
# iteration 700 / 1500: loss 2.145841
# iteration 800 / 1500: loss 2.146896
# iteration 900 / 1500: loss 2.165012
# iteration 1000 / 1500: loss 2.145179
# iteration 1100 / 1500: loss 2.168213
# iteration 1200 / 1500: loss 2.183782
# iteration 1300 / 1500: loss 2.181446
# iteration 1400 / 1500: loss 2.135858
# iteration 0 / 1500: loss 1198.530692
# iteration 100 / 1500: loss 49.126936
# iteration 200 / 1500: loss 4.001165
# iteration 300 / 1500: loss 2.258832
# iteration 400 / 1500: loss 2.163372
# iteration 500 / 1500: loss 2.135564
# iteration 600 / 1500: loss 2.176770
# iteration 700 / 1500: loss 2.179369
# iteration 800 / 1500: loss 2.155217
# iteration 900 / 1500: loss 2.228809
# iteration 1000 / 1500: loss 2.059305
# iteration 1100 / 1500: loss 2.153992
# iteration 1200 / 1500: loss 2.161302
# iteration 1300 / 1500: loss 2.111134
# iteration 1400 / 1500: loss 2.220518
# iteration 0 / 1500: loss 1289.396783
# iteration 100 / 1500: loss 42.317978
# iteration 200 / 1500: loss 3.430223
# iteration 300 / 1500: loss 2.169710
# iteration 400 / 1500: loss 2.142119
# iteration 500 / 1500: loss 2.159066
# iteration 600 / 1500: loss 2.168293
# iteration 700 / 1500: loss 2.170708
# iteration 800 / 1500: loss 2.105263
# iteration 900 / 1500: loss 2.182771
# iteration 1000 / 1500: loss 2.126032
# iteration 1100 / 1500: loss 2.190049
# iteration 1200 / 1500: loss 2.127519
# iteration 1300 / 1500: loss 2.141134
# iteration 1400 / 1500: loss 2.186647
# iteration 0 / 1500: loss 1379.960541
# iteration 100 / 1500: loss 36.233380
# iteration 200 / 1500: loss 2.975445
# iteration 300 / 1500: loss 2.264297
# iteration 400 / 1500: loss 2.193347
# iteration 500 / 1500: loss 2.158781
# iteration 600 / 1500: loss 2.232639
# iteration 700 / 1500: loss 2.163634
# iteration 800 / 1500: loss 2.144932
# iteration 900 / 1500: loss 2.157012
# iteration 1000 / 1500: loss 2.159060
# iteration 1100 / 1500: loss 2.111438
# iteration 1200 / 1500: loss 2.165599
# iteration 1300 / 1500: loss 2.137862
# iteration 1400 / 1500: loss 2.173030
# iteration 0 / 1500: loss 1463.709798
# iteration 100 / 1500: loss 30.894473
# iteration 200 / 1500: loss 2.720768
# iteration 300 / 1500: loss 2.244303
# iteration 400 / 1500: loss 2.131566
# iteration 500 / 1500: loss 2.190556
# iteration 600 / 1500: loss 2.154156
# iteration 700 / 1500: loss 2.170478
# iteration 800 / 1500: loss 2.213280
# iteration 900 / 1500: loss 2.156978
# iteration 1000 / 1500: loss 2.161102
# iteration 1100 / 1500: loss 2.137419
# iteration 1200 / 1500: loss 2.160387
# iteration 1300 / 1500: loss 2.221268
# iteration 1400 / 1500: loss 2.184831
# iteration 0 / 1500: loss 1534.183253
# iteration 100 / 1500: loss 25.984583
# iteration 200 / 1500: loss 2.568050
# iteration 300 / 1500: loss 2.164815
# iteration 400 / 1500: loss 2.109641
# iteration 500 / 1500: loss 2.159809
# iteration 600 / 1500: loss 2.197862
# iteration 700 / 1500: loss 2.233987
# iteration 800 / 1500: loss 2.135475
# iteration 900 / 1500: loss 2.189326
# iteration 1000 / 1500: loss 2.171560
# iteration 1100 / 1500: loss 2.220814
# iteration 1200 / 1500: loss 2.170610
# iteration 1300 / 1500: loss 2.147157
# iteration 1400 / 1500: loss 2.163952
# iteration 0 / 1500: loss 772.872716
# iteration 100 / 1500: loss 79.047390
# iteration 200 / 1500: loss 9.841277
# iteration 300 / 1500: loss 2.954832
# iteration 400 / 1500: loss 2.202585
# iteration 500 / 1500: loss 2.153591
# iteration 600 / 1500: loss 2.108606
# iteration 700 / 1500: loss 2.113842
# iteration 800 / 1500: loss 1.997635
# iteration 900 / 1500: loss 2.120644
# iteration 1000 / 1500: loss 2.090018
# iteration 1100 / 1500: loss 2.090679
# iteration 1200 / 1500: loss 2.145555
# iteration 1300 / 1500: loss 2.119664
# iteration 1400 / 1500: loss 2.148596
# iteration 0 / 1500: loss 853.206369
# iteration 100 / 1500: loss 67.985114
# iteration 200 / 1500: loss 7.179432
# iteration 300 / 1500: loss 2.613402
# iteration 400 / 1500: loss 2.132995
# iteration 500 / 1500: loss 2.148817
# iteration 600 / 1500: loss 2.094004
# iteration 700 / 1500: loss 2.096075
# iteration 800 / 1500: loss 2.164075
# iteration 900 / 1500: loss 2.193585
# iteration 1000 / 1500: loss 2.145777
# iteration 1100 / 1500: loss 2.128981
# iteration 1200 / 1500: loss 2.153785
# iteration 1300 / 1500: loss 2.082043
# iteration 1400 / 1500: loss 2.238849
# iteration 0 / 1500: loss 935.998613
# iteration 100 / 1500: loss 58.085698
# iteration 200 / 1500: loss 5.495479
# iteration 300 / 1500: loss 2.305673
# iteration 400 / 1500: loss 2.117284
# iteration 500 / 1500: loss 2.158257
# iteration 600 / 1500: loss 2.156297
# iteration 700 / 1500: loss 2.078733
# iteration 800 / 1500: loss 2.100585
# iteration 900 / 1500: loss 2.172478
# iteration 1000 / 1500: loss 2.244924
# iteration 1100 / 1500: loss 2.106569
# iteration 1200 / 1500: loss 2.089988
# iteration 1300 / 1500: loss 2.144956
# iteration 1400 / 1500: loss 2.092038
# iteration 0 / 1500: loss 1018.975422
# iteration 100 / 1500: loss 49.232068
# iteration 200 / 1500: loss 4.245902
# iteration 300 / 1500: loss 2.211954
# iteration 400 / 1500: loss 2.183061
# iteration 500 / 1500: loss 2.222123
# iteration 600 / 1500: loss 2.173573
# iteration 700 / 1500: loss 2.195058
# iteration 800 / 1500: loss 2.119848
# iteration 900 / 1500: loss 2.124368
# iteration 1000 / 1500: loss 2.113127
# iteration 1100 / 1500: loss 2.171186
# iteration 1200 / 1500: loss 2.148834
# iteration 1300 / 1500: loss 2.162760
# iteration 1400 / 1500: loss 2.124423
# iteration 0 / 1500: loss 1115.801373
# iteration 100 / 1500: loss 42.004324
# iteration 200 / 1500: loss 3.557905
# iteration 300 / 1500: loss 2.231998
# iteration 400 / 1500: loss 2.127841
# iteration 500 / 1500: loss 2.103255
# iteration 600 / 1500: loss 2.143649
# iteration 700 / 1500: loss 2.183999
# iteration 800 / 1500: loss 2.133033
# iteration 900 / 1500: loss 2.118622
# iteration 1000 / 1500: loss 2.128304
# iteration 1100 / 1500: loss 2.156434
# iteration 1200 / 1500: loss 2.172178
# iteration 1300 / 1500: loss 2.172663
# iteration 1400 / 1500: loss 2.120592
# iteration 0 / 1500: loss 1214.351484
# iteration 100 / 1500: loss 35.726916
# iteration 200 / 1500: loss 3.166241
# iteration 300 / 1500: loss 2.191575
# iteration 400 / 1500: loss 2.231857
# iteration 500 / 1500: loss 2.116471
# iteration 600 / 1500: loss 2.161910
# iteration 700 / 1500: loss 2.167998
# iteration 800 / 1500: loss 2.172172
# iteration 900 / 1500: loss 2.161086
# iteration 1000 / 1500: loss 2.237471
# iteration 1100 / 1500: loss 2.221947
# iteration 1200 / 1500: loss 2.131626
# iteration 1300 / 1500: loss 2.170335
# iteration 1400 / 1500: loss 2.167377
# iteration 0 / 1500: loss 1290.054356
# iteration 100 / 1500: loss 29.717470
# iteration 200 / 1500: loss 2.722341
# iteration 300 / 1500: loss 2.192467
# iteration 400 / 1500: loss 2.182327
# iteration 500 / 1500: loss 2.162449
# iteration 600 / 1500: loss 2.161966
# iteration 700 / 1500: loss 2.142733
# iteration 800 / 1500: loss 2.116928
# iteration 900 / 1500: loss 2.169230
# iteration 1000 / 1500: loss 2.170975
# iteration 1100 / 1500: loss 2.162161
# iteration 1200 / 1500: loss 2.210777
# iteration 1300 / 1500: loss 2.138628
# iteration 1400 / 1500: loss 2.205923
# iteration 0 / 1500: loss 1363.550941
# iteration 100 / 1500: loss 24.658814
# iteration 200 / 1500: loss 2.506574
# iteration 300 / 1500: loss 2.176746
# iteration 400 / 1500: loss 2.149254
# iteration 500 / 1500: loss 2.255087
# iteration 600 / 1500: loss 2.186219
# iteration 700 / 1500: loss 2.194724
# iteration 800 / 1500: loss 2.193449
# iteration 900 / 1500: loss 2.195217
# iteration 1000 / 1500: loss 2.129154
# iteration 1100 / 1500: loss 2.159604
# iteration 1200 / 1500: loss 2.185098
# iteration 1300 / 1500: loss 2.207203
# iteration 1400 / 1500: loss 2.174986
# iteration 0 / 1500: loss 1439.387602
# iteration 100 / 1500: loss 20.529128
# iteration 200 / 1500: loss 2.410478
# iteration 300 / 1500: loss 2.223882
# iteration 400 / 1500: loss 2.203388
# iteration 500 / 1500: loss 2.138634
# iteration 600 / 1500: loss 2.153977
# iteration 700 / 1500: loss 2.116032
# iteration 800 / 1500: loss 2.220608
# iteration 900 / 1500: loss 2.190644
# iteration 1000 / 1500: loss 2.137930
# iteration 1100 / 1500: loss 2.189446
# iteration 1200 / 1500: loss 2.186499
# iteration 1300 / 1500: loss 2.223443
# iteration 1400 / 1500: loss 2.252217
# iteration 0 / 1500: loss 1551.753486
# iteration 100 / 1500: loss 17.517697
# iteration 200 / 1500: loss 2.323935
# iteration 300 / 1500: loss 2.211540
# iteration 400 / 1500: loss 2.160650
# iteration 500 / 1500: loss 2.149134
# iteration 600 / 1500: loss 2.184483
# iteration 700 / 1500: loss 2.266256
# iteration 800 / 1500: loss 2.172411
# iteration 900 / 1500: loss 2.148404
# iteration 1000 / 1500: loss 2.181954
# iteration 1100 / 1500: loss 2.182980
# iteration 1200 / 1500: loss 2.211658
# iteration 1300 / 1500: loss 2.160788
# iteration 1400 / 1500: loss 2.186528
# iteration 0 / 1500: loss 768.548836
# iteration 100 / 1500: loss 63.344750
# iteration 200 / 1500: loss 7.011629
# iteration 300 / 1500: loss 2.546144
# iteration 400 / 1500: loss 2.145682
# iteration 500 / 1500: loss 2.157620
# iteration 600 / 1500: loss 2.134605
# iteration 700 / 1500: loss 2.084790
# iteration 800 / 1500: loss 2.147716
# iteration 900 / 1500: loss 2.134733
# iteration 1000 / 1500: loss 2.138668
# iteration 1100 / 1500: loss 2.078928
# iteration 1200 / 1500: loss 2.160229
# iteration 1300 / 1500: loss 2.093797
# iteration 1400 / 1500: loss 2.143815
# iteration 0 / 1500: loss 866.087215
# iteration 100 / 1500: loss 54.065447
# iteration 200 / 1500: loss 5.249899
# iteration 300 / 1500: loss 2.323190
# iteration 400 / 1500: loss 2.093337
# iteration 500 / 1500: loss 2.051581
# iteration 600 / 1500: loss 2.131733
# iteration 700 / 1500: loss 2.172650
# iteration 800 / 1500: loss 2.136282
# iteration 900 / 1500: loss 2.116012
# iteration 1000 / 1500: loss 2.174115
# iteration 1100 / 1500: loss 2.115671
# iteration 1200 / 1500: loss 2.169486
# iteration 1300 / 1500: loss 2.137421
# iteration 1400 / 1500: loss 2.139117
# iteration 0 / 1500: loss 945.947945
# iteration 100 / 1500: loss 45.013037
# iteration 200 / 1500: loss 4.137030
# iteration 300 / 1500: loss 2.213780
# iteration 400 / 1500: loss 2.181507
# iteration 500 / 1500: loss 2.162994
# iteration 600 / 1500: loss 2.192948
# iteration 700 / 1500: loss 2.110445
# iteration 800 / 1500: loss 2.113770
# iteration 900 / 1500: loss 2.146047
# iteration 1000 / 1500: loss 2.141819
# iteration 1100 / 1500: loss 2.126853
# iteration 1200 / 1500: loss 2.120699
# iteration 1300 / 1500: loss 2.110521
# iteration 1400 / 1500: loss 2.179305
# iteration 0 / 1500: loss 1020.351194
# iteration 100 / 1500: loss 37.103846
# iteration 200 / 1500: loss 3.333655
# iteration 300 / 1500: loss 2.214094
# iteration 400 / 1500: loss 2.135941
# iteration 500 / 1500: loss 2.142186
# iteration 600 / 1500: loss 2.137521
# iteration 700 / 1500: loss 2.129421
# iteration 800 / 1500: loss 2.152615
# iteration 900 / 1500: loss 2.123881
# iteration 1000 / 1500: loss 2.179324
# iteration 1100 / 1500: loss 2.126580
# iteration 1200 / 1500: loss 2.101073
# iteration 1300 / 1500: loss 2.157455
# iteration 1400 / 1500: loss 2.154680
# iteration 0 / 1500: loss 1115.616479
# iteration 100 / 1500: loss 30.804043
# iteration 200 / 1500: loss 2.900006
# iteration 300 / 1500: loss 2.212480
# iteration 400 / 1500: loss 2.141476
# iteration 500 / 1500: loss 2.129333
# iteration 600 / 1500: loss 2.126497
# iteration 700 / 1500: loss 2.136475
# iteration 800 / 1500: loss 2.100914
# iteration 900 / 1500: loss 2.161054
# iteration 1000 / 1500: loss 2.177989
# iteration 1100 / 1500: loss 2.163819
# iteration 1200 / 1500: loss 2.121295
# iteration 1300 / 1500: loss 2.168309
# iteration 1400 / 1500: loss 2.154093
# iteration 0 / 1500: loss 1199.849053
# iteration 100 / 1500: loss 25.431681
# iteration 200 / 1500: loss 2.642994
# iteration 300 / 1500: loss 2.145301
# iteration 400 / 1500: loss 2.110286
# iteration 500 / 1500: loss 2.160841
# iteration 600 / 1500: loss 2.183616
# iteration 700 / 1500: loss 2.142098
# iteration 800 / 1500: loss 2.170819
# iteration 900 / 1500: loss 2.149030
# iteration 1000 / 1500: loss 2.190595
# iteration 1100 / 1500: loss 2.148949
# iteration 1200 / 1500: loss 2.186027
# iteration 1300 / 1500: loss 2.159134
# iteration 1400 / 1500: loss 2.167466
# iteration 0 / 1500: loss 1291.745662
# iteration 100 / 1500: loss 21.005404
# iteration 200 / 1500: loss 2.471788
# iteration 300 / 1500: loss 2.156497
# iteration 400 / 1500: loss 2.229966
# iteration 500 / 1500: loss 2.108288
# iteration 600 / 1500: loss 2.148314
# iteration 700 / 1500: loss 2.159164
# iteration 800 / 1500: loss 2.190762
# iteration 900 / 1500: loss 2.147865
# iteration 1000 / 1500: loss 2.212177
# iteration 1100 / 1500: loss 2.145978
# iteration 1200 / 1500: loss 2.175783
# iteration 1300 / 1500: loss 2.139096
# iteration 1400 / 1500: loss 2.191292
# iteration 0 / 1500: loss 1391.983630
# iteration 100 / 1500: loss 17.441223
# iteration 200 / 1500: loss 2.315261
# iteration 300 / 1500: loss 2.201521
# iteration 400 / 1500: loss 2.239105
# iteration 500 / 1500: loss 2.210740
# iteration 600 / 1500: loss 2.158617
# iteration 700 / 1500: loss 2.137640
# iteration 800 / 1500: loss 2.156254
# iteration 900 / 1500: loss 2.199460
# iteration 1000 / 1500: loss 2.161667
# iteration 1100 / 1500: loss 2.184340
# iteration 1200 / 1500: loss 2.247739
# iteration 1300 / 1500: loss 2.173671
# iteration 1400 / 1500: loss 2.145677
# iteration 0 / 1500: loss 1459.488835
# iteration 100 / 1500: loss 14.284372
# iteration 200 / 1500: loss 2.241530
# iteration 300 / 1500: loss 2.152364
# iteration 400 / 1500: loss 2.151537
# iteration 500 / 1500: loss 2.179769
# iteration 600 / 1500: loss 2.197735
# iteration 700 / 1500: loss 2.238947
# iteration 800 / 1500: loss 2.215848
# iteration 900 / 1500: loss 2.139172
# iteration 1000 / 1500: loss 2.158145
# iteration 1100 / 1500: loss 2.186712
# iteration 1200 / 1500: loss 2.159470
# iteration 1300 / 1500: loss 2.191182
# iteration 1400 / 1500: loss 2.231016
# iteration 0 / 1500: loss 1530.299816
# iteration 100 / 1500: loss 11.764603
# iteration 200 / 1500: loss 2.208330
# iteration 300 / 1500: loss 2.175908
# iteration 400 / 1500: loss 2.157107
# iteration 500 / 1500: loss 2.187086
# iteration 600 / 1500: loss 2.153887
# iteration 700 / 1500: loss 2.103370
# iteration 800 / 1500: loss 2.239964
# iteration 900 / 1500: loss 2.187788
# iteration 1000 / 1500: loss 2.218915
# iteration 1100 / 1500: loss 2.137865
# iteration 1200 / 1500: loss 2.189349
# iteration 1300 / 1500: loss 2.194532
# iteration 1400 / 1500: loss 2.192599
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.347490 val accuracy: 0.360000
# lr 1.000000e-07 reg 2.777778e+04 train accuracy: 0.348531 val accuracy: 0.373000
# lr 1.000000e-07 reg 3.055556e+04 train accuracy: 0.340673 val accuracy: 0.360000
# lr 1.000000e-07 reg 3.333333e+04 train accuracy: 0.336939 val accuracy: 0.347000
# lr 1.000000e-07 reg 3.611111e+04 train accuracy: 0.338755 val accuracy: 0.355000
# lr 1.000000e-07 reg 3.888889e+04 train accuracy: 0.335694 val accuracy: 0.349000
# lr 1.000000e-07 reg 4.166667e+04 train accuracy: 0.334980 val accuracy: 0.351000
# lr 1.000000e-07 reg 4.444444e+04 train accuracy: 0.333959 val accuracy: 0.350000
# lr 1.000000e-07 reg 4.722222e+04 train accuracy: 0.324551 val accuracy: 0.347000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.327306 val accuracy: 0.344000
# lr 1.444444e-07 reg 2.500000e+04 train accuracy: 0.347204 val accuracy: 0.365000
# lr 1.444444e-07 reg 2.777778e+04 train accuracy: 0.351327 val accuracy: 0.375000
# lr 1.444444e-07 reg 3.055556e+04 train accuracy: 0.341224 val accuracy: 0.356000
# lr 1.444444e-07 reg 3.333333e+04 train accuracy: 0.343469 val accuracy: 0.362000
# lr 1.444444e-07 reg 3.611111e+04 train accuracy: 0.337959 val accuracy: 0.351000
# lr 1.444444e-07 reg 3.888889e+04 train accuracy: 0.336082 val accuracy: 0.350000
# lr 1.444444e-07 reg 4.166667e+04 train accuracy: 0.329816 val accuracy: 0.347000
# lr 1.444444e-07 reg 4.444444e+04 train accuracy: 0.332408 val accuracy: 0.355000
# lr 1.444444e-07 reg 4.722222e+04 train accuracy: 0.330163 val accuracy: 0.341000
# lr 1.444444e-07 reg 5.000000e+04 train accuracy: 0.321224 val accuracy: 0.342000
# lr 1.888889e-07 reg 2.500000e+04 train accuracy: 0.351000 val accuracy: 0.364000
# lr 1.888889e-07 reg 2.777778e+04 train accuracy: 0.345898 val accuracy: 0.350000
# lr 1.888889e-07 reg 3.055556e+04 train accuracy: 0.347082 val accuracy: 0.357000
# lr 1.888889e-07 reg 3.333333e+04 train accuracy: 0.341327 val accuracy: 0.349000
# lr 1.888889e-07 reg 3.611111e+04 train accuracy: 0.336327 val accuracy: 0.351000
# lr 1.888889e-07 reg 3.888889e+04 train accuracy: 0.337020 val accuracy: 0.355000
# lr 1.888889e-07 reg 4.166667e+04 train accuracy: 0.337551 val accuracy: 0.343000
# lr 1.888889e-07 reg 4.444444e+04 train accuracy: 0.331224 val accuracy: 0.343000
# lr 1.888889e-07 reg 4.722222e+04 train accuracy: 0.328224 val accuracy: 0.349000
# lr 1.888889e-07 reg 5.000000e+04 train accuracy: 0.325204 val accuracy: 0.340000
# lr 2.333333e-07 reg 2.500000e+04 train accuracy: 0.348429 val accuracy: 0.360000
# lr 2.333333e-07 reg 2.777778e+04 train accuracy: 0.352000 val accuracy: 0.364000
# lr 2.333333e-07 reg 3.055556e+04 train accuracy: 0.343184 val accuracy: 0.357000
# lr 2.333333e-07 reg 3.333333e+04 train accuracy: 0.341184 val accuracy: 0.355000
# lr 2.333333e-07 reg 3.611111e+04 train accuracy: 0.335735 val accuracy: 0.360000
# lr 2.333333e-07 reg 3.888889e+04 train accuracy: 0.337531 val accuracy: 0.353000
# lr 2.333333e-07 reg 4.166667e+04 train accuracy: 0.338327 val accuracy: 0.348000
# lr 2.333333e-07 reg 4.444444e+04 train accuracy: 0.339245 val accuracy: 0.355000
# lr 2.333333e-07 reg 4.722222e+04 train accuracy: 0.331857 val accuracy: 0.343000
# lr 2.333333e-07 reg 5.000000e+04 train accuracy: 0.328143 val accuracy: 0.337000
# lr 2.777778e-07 reg 2.500000e+04 train accuracy: 0.356224 val accuracy: 0.370000
# lr 2.777778e-07 reg 2.777778e+04 train accuracy: 0.347388 val accuracy: 0.359000
# lr 2.777778e-07 reg 3.055556e+04 train accuracy: 0.340102 val accuracy: 0.344000
# lr 2.777778e-07 reg 3.333333e+04 train accuracy: 0.349429 val accuracy: 0.369000
# lr 2.777778e-07 reg 3.611111e+04 train accuracy: 0.340837 val accuracy: 0.350000
# lr 2.777778e-07 reg 3.888889e+04 train accuracy: 0.342061 val accuracy: 0.363000
# lr 2.777778e-07 reg 4.166667e+04 train accuracy: 0.336327 val accuracy: 0.350000
# lr 2.777778e-07 reg 4.444444e+04 train accuracy: 0.333122 val accuracy: 0.348000
# lr 2.777778e-07 reg 4.722222e+04 train accuracy: 0.325551 val accuracy: 0.330000
# lr 2.777778e-07 reg 5.000000e+04 train accuracy: 0.333286 val accuracy: 0.351000
# lr 3.222222e-07 reg 2.500000e+04 train accuracy: 0.342673 val accuracy: 0.355000
# lr 3.222222e-07 reg 2.777778e+04 train accuracy: 0.342755 val accuracy: 0.357000
# lr 3.222222e-07 reg 3.055556e+04 train accuracy: 0.347735 val accuracy: 0.357000
# lr 3.222222e-07 reg 3.333333e+04 train accuracy: 0.339347 val accuracy: 0.338000
# lr 3.222222e-07 reg 3.611111e+04 train accuracy: 0.339673 val accuracy: 0.361000
# lr 3.222222e-07 reg 3.888889e+04 train accuracy: 0.337571 val accuracy: 0.347000
# lr 3.222222e-07 reg 4.166667e+04 train accuracy: 0.333796 val accuracy: 0.347000
# lr 3.222222e-07 reg 4.444444e+04 train accuracy: 0.325184 val accuracy: 0.331000
# lr 3.222222e-07 reg 4.722222e+04 train accuracy: 0.334531 val accuracy: 0.351000
# lr 3.222222e-07 reg 5.000000e+04 train accuracy: 0.330143 val accuracy: 0.350000
# lr 3.666667e-07 reg 2.500000e+04 train accuracy: 0.341755 val accuracy: 0.365000
# lr 3.666667e-07 reg 2.777778e+04 train accuracy: 0.347694 val accuracy: 0.356000
# lr 3.666667e-07 reg 3.055556e+04 train accuracy: 0.341367 val accuracy: 0.362000
# lr 3.666667e-07 reg 3.333333e+04 train accuracy: 0.334918 val accuracy: 0.349000
# lr 3.666667e-07 reg 3.611111e+04 train accuracy: 0.344837 val accuracy: 0.358000
# lr 3.666667e-07 reg 3.888889e+04 train accuracy: 0.334898 val accuracy: 0.328000
# lr 3.666667e-07 reg 4.166667e+04 train accuracy: 0.328592 val accuracy: 0.343000
# lr 3.666667e-07 reg 4.444444e+04 train accuracy: 0.339408 val accuracy: 0.353000
# lr 3.666667e-07 reg 4.722222e+04 train accuracy: 0.321694 val accuracy: 0.331000
# lr 3.666667e-07 reg 5.000000e+04 train accuracy: 0.319898 val accuracy: 0.339000
# lr 4.111111e-07 reg 2.500000e+04 train accuracy: 0.351939 val accuracy: 0.367000
# lr 4.111111e-07 reg 2.777778e+04 train accuracy: 0.350204 val accuracy: 0.368000
# lr 4.111111e-07 reg 3.055556e+04 train accuracy: 0.333510 val accuracy: 0.343000
# lr 4.111111e-07 reg 3.333333e+04 train accuracy: 0.336286 val accuracy: 0.357000
# lr 4.111111e-07 reg 3.611111e+04 train accuracy: 0.331224 val accuracy: 0.353000
# lr 4.111111e-07 reg 3.888889e+04 train accuracy: 0.338000 val accuracy: 0.347000
# lr 4.111111e-07 reg 4.166667e+04 train accuracy: 0.336714 val accuracy: 0.338000
# lr 4.111111e-07 reg 4.444444e+04 train accuracy: 0.329633 val accuracy: 0.338000
# lr 4.111111e-07 reg 4.722222e+04 train accuracy: 0.330000 val accuracy: 0.348000
# lr 4.111111e-07 reg 5.000000e+04 train accuracy: 0.331735 val accuracy: 0.350000
# lr 4.555556e-07 reg 2.500000e+04 train accuracy: 0.345510 val accuracy: 0.344000
# lr 4.555556e-07 reg 2.777778e+04 train accuracy: 0.347755 val accuracy: 0.349000
# lr 4.555556e-07 reg 3.055556e+04 train accuracy: 0.348286 val accuracy: 0.356000
# lr 4.555556e-07 reg 3.333333e+04 train accuracy: 0.339163 val accuracy: 0.346000
# lr 4.555556e-07 reg 3.611111e+04 train accuracy: 0.335163 val accuracy: 0.351000
# lr 4.555556e-07 reg 3.888889e+04 train accuracy: 0.332898 val accuracy: 0.353000
# lr 4.555556e-07 reg 4.166667e+04 train accuracy: 0.322408 val accuracy: 0.336000
# lr 4.555556e-07 reg 4.444444e+04 train accuracy: 0.332286 val accuracy: 0.348000
# lr 4.555556e-07 reg 4.722222e+04 train accuracy: 0.325224 val accuracy: 0.337000
# lr 4.555556e-07 reg 5.000000e+04 train accuracy: 0.319816 val accuracy: 0.337000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.351816 val accuracy: 0.348000
# lr 5.000000e-07 reg 2.777778e+04 train accuracy: 0.345163 val accuracy: 0.361000
# lr 5.000000e-07 reg 3.055556e+04 train accuracy: 0.344041 val accuracy: 0.366000
# lr 5.000000e-07 reg 3.333333e+04 train accuracy: 0.338367 val accuracy: 0.354000
# lr 5.000000e-07 reg 3.611111e+04 train accuracy: 0.328735 val accuracy: 0.340000
# lr 5.000000e-07 reg 3.888889e+04 train accuracy: 0.330408 val accuracy: 0.336000
# lr 5.000000e-07 reg 4.166667e+04 train accuracy: 0.327020 val accuracy: 0.338000
# lr 5.000000e-07 reg 4.444444e+04 train accuracy: 0.325612 val accuracy: 0.342000
# lr 5.000000e-07 reg 4.722222e+04 train accuracy: 0.331163 val accuracy: 0.340000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.321735 val accuracy: 0.343000
# best validation accuracy achieved during cross-validation: 0.375000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.358000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])

# %% [markdown]
# *Many thanks to Stanford CS231n for permission to use their materials!*
